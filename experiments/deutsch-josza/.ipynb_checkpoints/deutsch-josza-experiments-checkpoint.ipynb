# %%
#initialization
import matplotlib.pyplot as plt
import numpy as np

# importing Qiskit
from qiskit import IBMQ, Aer, assemble, transpile
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit.providers.ibmq import least_busy

# import basic plot tools
from qiskit.visualization import plot_histogram

# Load IBM Q account and get the least busy backend device
provider = IBMQ.load_account()
provider = IBMQ.get_provider("ibm-q")
# provider = IBMQ.get_provider(hub='ibm-q-education', group='yale-uni-2', project='cpsc647-quantum')
# device = provider.get_backend('ibmq_lima') #run on ibmq_lima (5-qbit QC)

# %%
# device_names =  ['ibmq_lima', 'ibmq_bogota', 'ibmq_santiago', 'ibmq_manila', 'ibmq_quito', 'ibmq_belem', 'ibmq_casablanca', 'ibmq_jakarta', 'ibm_lagos', 'ibm_perth'  ]
device_names =  ['ibmq_lima', 'ibmq_bogota', 'ibmq_santiago', 'ibmq_manila', 'ibmq_quito', 'ibmq_belem']
device = [0]*len(device_names)
for i in range(len(device_names)):
    device[i] = provider.get_backend(device_names[i])
    print("Device", i , "=", device[i])
# Out:
# Device 0 = ibmq_lima
# Device 1 = ibmq_bogota
# Device 2 = ibmq_santiago
# Device 3 = ibmq_manila
# Device 4 = ibmq_quito
# Device 5 = ibmq_belem

# %%
def dj_oracle(case, n):
    # We need to make a QuantumCircuit object to return
    # This circuit has n+1 qubits: the size of the input,
    # plus one output qubit
    oracle_qc = QuantumCircuit(n+1)
    
    # First, let's deal with the case in which oracle is balanced
    if case == "balanced":
        # First generate a random number that tells us which CNOTs to
        # wrap in X-gates:
        b = np.random.randint(1,2**n)
        # Next, format 'b' as a binary string of length 'n', padded with zeros:
        b_str = format(b, '0'+str(n)+'b')
        # Next, we place the first X-gates. Each digit in our binary string 
        # corresponds to a qubit, if the digit is 0, we do nothing, if it's 1
        # we apply an X-gate to that qubit:
        for qubit in range(len(b_str)):
            if b_str[qubit] == '1':
                oracle_qc.x(qubit)
        # Do the controlled-NOT gates for each qubit, using the output qubit 
        # as the target:
        for qubit in range(n):
            oracle_qc.cx(qubit, n)
        # Next, place the final X-gates
        for qubit in range(len(b_str)):
            if b_str[qubit] == '1':
                oracle_qc.x(qubit)

    # Case in which oracle is constant
    if case == "constant":
        # First decide what the fixed output of the oracle will be
        # (either always 0 or always 1)
        output = np.random.randint(2)
        if output == 1:
            oracle_qc.x(n)
    
    oracle_gate = oracle_qc.to_gate()
    oracle_gate.name = "Oracle" # To show when we display the circuit
    return oracle_gate


def dj_algorithm(oracle, n):
    dj_circuit = QuantumCircuit(n+1, n)
    # Set up the output qubit:
    dj_circuit.x(n)
    dj_circuit.h(n)
    # And set up the input register:
    for qubit in range(n):
        dj_circuit.h(qubit)
    # Let's append the oracle gate to our circuit:
    dj_circuit.append(oracle, range(n+1))
    # Finally, perform the H-gates again and measure:
    for qubit in range(n):
        dj_circuit.h(qubit)
    
    
    for i in range(n):
        dj_circuit.measure(i, i)
    
    return dj_circuit

def dj_mal(copies):
    oracle = dj_oracle("balanced",2)
    dj_circuit = QuantumCircuit(5, 4)
#     dj_circuit = QuantumCircuit(5)
    
    dj_circuit.barrier()
    # Set up the output qubit:
    dj_circuit.x(2)
    dj_circuit.h(2)
    # And set up the input register:
    for qubit in range(2):
        dj_circuit.h(qubit)
    # Let's append the oracle gate to our circuit:
    
#     dj_circuit.append(oracle, range(2+1))
    dj_circuit.append(oracle, [0,1,2])
    # Finally, perform the H-gates again and measure:
    for qubit in range(2):
        dj_circuit.h(qubit)
    
    for i in range(copies):
        dj_circuit.cx(3,4)
#         dj_circuit.h(3)
#         dj_circuit.delay(0, qarg = 3)
#         dj_circuit.cx(4,3)
        dj_circuit.delay(0, qarg = 3)
        
    dj_circuit.barrier()
#     for i in range(2):
#         dj_circuit.measure(i, i)
    
    dj_circuit.measure(0, 0)
    dj_circuit.measure(1, 1)
    dj_circuit.measure(3, 2)
    dj_circuit.measure(4, 3)
    
    return dj_circuit

# %%
n=2
oracle = dj_oracle("balanced",n)
d1 = dj_algorithm(oracle, n)
dj = dj_mal(10)

print(d1)
print(dj)
# Out:
#      ┌───┐     ┌─────────┐┌───┐┌─┐
# q_0: ┤ H ├─────┤0        ├┤ H ├┤M├───
#      ├───┤     │         │├───┤└╥┘┌─┐
# q_1: ┤ H ├─────┤1 Oracle ├┤ H ├─╫─┤M├
#      ├───┤┌───┐│         │└───┘ ║ └╥┘
# q_2: ┤ X ├┤ H ├┤2        ├──────╫──╫─
#      └───┘└───┘└─────────┘      ║  ║
# c: 2/═══════════════════════════╩══╩═
#                                 0  1
#       ░ ┌───┐                ┌─────────┐     ┌───┐                           »
# q_0: ─░─┤ H ├────────────────┤0        ├─────┤ H ├───────────────────────────»
#       ░ ├───┤                │         │     ├───┤                           »
# q_1: ─░─┤ H ├────────────────┤1 Oracle ├─────┤ H ├───────────────────────────»
#       ░ ├───┤     ┌───┐      │         │     └───┘                           »
# q_2: ─░─┤ X ├─────┤ H ├──────┤2        ├─────────────────────────────────────»
#       ░ └───┘┌────┴───┴─────┐└─────────┘┌──────────────┐     ┌──────────────┐»
# q_3: ─░───■──┤ Delay(0[dt]) ├─────■─────┤ Delay(0[dt]) ├──■──┤ Delay(0[dt]) ├»
#       ░ ┌─┴─┐└──────────────┘   ┌─┴─┐   └──────────────┘┌─┴─┐└──────────────┘»
# q_4: ─░─┤ X ├───────────────────┤ X ├───────────────────┤ X ├────────────────»
#       ░ └───┘                   └───┘                   └───┘                »
# c: 4/════════════════════════════════════════════════════════════════════════»
#                                                                              »
# «                                                                         »
# «q_0: ────────────────────────────────────────────────────────────────────»
# «                                                                         »
# «q_1: ────────────────────────────────────────────────────────────────────»
# «                                                                         »
# «q_2: ────────────────────────────────────────────────────────────────────»
# «          ┌──────────────┐     ┌──────────────┐     ┌──────────────┐     »
# «q_3: ──■──┤ Delay(0[dt]) ├──■──┤ Delay(0[dt]) ├──■──┤ Delay(0[dt]) ├──■──»
# «     ┌─┴─┐└──────────────┘┌─┴─┐└──────────────┘┌─┴─┐└──────────────┘┌─┴─┐»
# «q_4: ┤ X ├────────────────┤ X ├────────────────┤ X ├────────────────┤ X ├»
# «     └───┘                └───┘                └───┘                └───┘»
# «c: 4/════════════════════════════════════════════════════════════════════»
# «                                                                         »
# «                                                                    »
# «q_0: ───────────────────────────────────────────────────────────────»
# «                                                                    »
# «q_1: ───────────────────────────────────────────────────────────────»
# «                                                                    »
# «q_2: ───────────────────────────────────────────────────────────────»
# «     ┌──────────────┐     ┌──────────────┐     ┌──────────────┐     »
# «q_3: ┤ Delay(0[dt]) ├──■──┤ Delay(0[dt]) ├──■──┤ Delay(0[dt]) ├──■──»
# «     └──────────────┘┌─┴─┐└──────────────┘┌─┴─┐└──────────────┘┌─┴─┐»
# «q_4: ────────────────┤ X ├────────────────┤ X ├────────────────┤ X ├»
# «                     └───┘                └───┘                └───┘»
# «c: 4/═══════════════════════════════════════════════════════════════»
# «                                                                    »
# «                      ░ ┌─┐
# «q_0: ─────────────────░─┤M├─────────
# «                      ░ └╥┘┌─┐
# «q_1: ─────────────────░──╫─┤M├──────
# «                      ░  ║ └╥┘
# «q_2: ─────────────────░──╫──╫───────
# «     ┌──────────────┐ ░  ║  ║ ┌─┐
# «q_3: ┤ Delay(0[dt]) ├─░──╫──╫─┤M├───
# «     └──────────────┘ ░  ║  ║ └╥┘┌─┐
# «q_4: ─────────────────░──╫──╫──╫─┤M├
# «                      ░  ║  ║  ║ └╥┘
# «c: 4/════════════════════╩══╩══╩══╩═
# «                         0  1  2  3

# %%
aer_sim = Aer.get_backend('aer_simulator')
transpiled_circuit = transpile(dj, aer_sim)
qobj = assemble(transpiled_circuit)
results = aer_sim.run(qobj).result()
counts = results.get_counts()
plot_histogram(counts)

# %%
print("Running on device: ", device[0])
from qiskit.tools.monitor import job_monitor
transpiled_dj = transpile(dj, device[0], optimization_level=3, scheduling_method='alap')
# Out:
# Running on device:  ibmq_lima

# %%
job = device[0].run(transpiled_dj)
job_monitor(job, interval=2)
# Out:
# Job Status: job has successfully run

# %%
results = job.result()
answer = results.get_counts()
plot_histogram(answer)

# %%
transpiled_dj.draw('mpl')

# %%
from qiskit.tools.monitor import job_monitor

iterations = 30
f = open("dj_CX_alap.txt", "w")
backend = device[0]
answer= [0]*iterations
f.write(str(backend))
f.write(str("\n"))
for i in range(iterations):
    dj = dj_mal(i)
    print("Running on device: ", backend)
#     transpiled_dj = transpile(dj, backend, optimization_level=3, scheduling_method='alap')
    transpiled_dj = transpile(dj, backend, optimization_level=0, scheduling_method='alap')
    job = backend.run(transpiled_dj) 
    job_monitor(job, interval=2)

    results = job.result()
    answer[i] = results.get_counts()
    
    prob = int(answer[i]['11'])/1000
    print(i, prob)
    f.write(str(i))
    f.write(str(", "))
    f.write(str(prob))
    f.write(str("\n"))
    
f.close()
# Out:
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 0 0.835
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 1 0.93
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 2 0.897
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 3 0.92
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 4 0.899
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 5 0.93
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 6 0.921
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 7 0.94
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 8 0.872
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 9 0.871
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 10 0.884
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 11 0.909
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 12 0.91
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 13 0.889
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 14 0.89
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 15 0.895
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 16 0.926
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 17 0.913
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 18 0.888
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 19 0.914
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 20 0.928
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 21 0.881
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 22 0.896
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 23 0.869
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 24 0.863
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 25 0.909
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 26 0.91
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 27 0.86
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 28 0.861
# Running on device:  ibmq_lima
# Job Status: job has successfully run
# 29 0.909

# %%
transpiled_dj.draw('mpl')

# %%
transpiled_dj = [0]*len(device)
for i in range(len(device)):
    print("============================================")
    print(device[i])
    transpiled_dj[i] = transpile(dj, device[i], optimization_level=3, scheduling_method='alap')
    print(transpiled_dj[i])
    print("============================================")
# Out:
# ============================================
# ibmq_lima
#                ┌──────────────────┐                                 »
# ancilla_0 -> 0 ┤ Delay(28816[dt]) ├─────────────────────────────────»
#                ├─────────────────┬┘┌──────────┐   ┌────┐   ┌───────┐»
#       q_1 -> 1 ┤ Delay(2176[dt]) ├─┤ Rz(-π/2) ├───┤ √X ├───┤ Rz(π) ├»
#                ├─────────────────┴┐└──────────┘   └────┘   └───────┘»
# ancilla_1 -> 2 ┤ Delay(28816[dt]) ├─────────────────────────────────»
#                └───┬─────────┬────┘   ┌────┐   ┌──────────┐  ┌───┐  »
#       q_2 -> 3 ────┤ Rz(π/2) ├────────┤ √X ├───┤ Rz(-π/2) ├──┤ X ├──»
#                    ├─────────┴┐       ├────┤   └┬───────┬─┘  └─┬─┘  »
#       q_0 -> 4 ────┤ Rz(-π/2) ├───────┤ √X ├────┤ Rz(π) ├──────■────»
#                    └──────────┘       └────┘    └───────┘           »
#           c: 2/═════════════════════════════════════════════════════»
#                                                                     »
# «
# «ancilla_0 -> 0 ─────────────────────────────────────────────────────────
# «                                         ┌────┐       ┌──────────┐   ┌─┐
# «      q_1 -> 1 ─────────■────────────────┤ √X ├───────┤ Rz(-π/2) ├───┤M├
# «                        │                └────┘       └──────────┘   └╥┘
# «ancilla_1 -> 2 ─────────┼─────────────────────────────────────────────╫─
# «                      ┌─┴─┐       ┌──────────────────┐                ║
# «      q_2 -> 3 ───────┤ X ├───────┤ Delay(24240[dt]) ├────────────────╫─
# «               ┌──────┴───┴──────┐└──────┬────┬──────┘┌──────────┐┌─┐ ║
# «      q_0 -> 4 ┤ Delay(2240[dt]) ├───────┤ √X ├───────┤ Rz(-π/2) ├┤M├─╫─
# «               └─────────────────┘       └────┘       └──────────┘└╥┘ ║
# «          c: 2/════════════════════════════════════════════════════╩══╩═
# «                                                                   0  1
# ============================================
# ============================================
# ibmq_bogota
#                ┌─────────────────┐ ┌──────────┐   ┌────┐   ┌───────┐»
#       q_1 -> 0 ┤ Delay(1504[dt]) ├─┤ Rz(-π/2) ├───┤ √X ├───┤ Rz(π) ├»
#                └───┬─────────┬───┘ └──┬────┬──┘┌──┴────┴──┐└─┬───┬─┘»
#       q_2 -> 1 ────┤ Rz(π/2) ├────────┤ √X ├───┤ Rz(-π/2) ├──┤ X ├──»
#                    ├─────────┴┐       ├────┤   └┬───────┬─┘  └─┬─┘  »
#       q_0 -> 2 ────┤ Rz(-π/2) ├───────┤ √X ├────┤ Rz(π) ├──────■────»
#                ┌───┴──────────┴───┐   └────┘    └───────┘           »
# ancilla_0 -> 3 ┤ Delay(27648[dt]) ├─────────────────────────────────»
#                ├──────────────────┤                                 »
# ancilla_1 -> 4 ┤ Delay(27648[dt]) ├─────────────────────────────────»
#                └──────────────────┘                                 »
#           c: 2/═════════════════════════════════════════════════════»
#                                                                     »
# «                                         ┌────┐       ┌──────────┐   ┌─┐
# «      q_1 -> 0 ─────────■────────────────┤ √X ├───────┤ Rz(-π/2) ├───┤M├
# «                      ┌─┴─┐       ┌──────┴────┴──────┐└──────────┘   └╥┘
# «      q_2 -> 1 ───────┤ X ├───────┤ Delay(22880[dt]) ├────────────────╫─
# «               ┌──────┴───┴──────┐└──────┬────┬──────┘┌──────────┐┌─┐ ║
# «      q_0 -> 2 ┤ Delay(3104[dt]) ├───────┤ √X ├───────┤ Rz(-π/2) ├┤M├─╫─
# «               └─────────────────┘       └────┘       └──────────┘└╥┘ ║
# «ancilla_0 -> 3 ────────────────────────────────────────────────────╫──╫─
# «                                                                   ║  ║
# «ancilla_1 -> 4 ────────────────────────────────────────────────────╫──╫─
# «                                                                   ║  ║
# «          c: 2/════════════════════════════════════════════════════╩══╩═
# «                                                                   0  1
# ============================================
# ============================================
# ibmq_santiago
#                ┌──────────────────┐                                 »
# ancilla_0 -> 0 ┤ Delay(21632[dt]) ├─────────────────────────────────»
#                ├──────────────────┤                                 »
# ancilla_1 -> 1 ┤ Delay(21632[dt]) ├─────────────────────────────────»
#                ├─────────────────┬┘┌──────────┐   ┌────┐   ┌───────┐»
#       q_1 -> 2 ┤ Delay(1536[dt]) ├─┤ Rz(-π/2) ├───┤ √X ├───┤ Rz(π) ├»
#                └───┬─────────┬───┘ └──┬────┬──┘┌──┴────┴──┐└─┬───┬─┘»
#       q_2 -> 3 ────┤ Rz(π/2) ├────────┤ √X ├───┤ Rz(-π/2) ├──┤ X ├──»
#                    ├─────────┴┐       ├────┤   └┬───────┬─┘  └─┬─┘  »
#       q_0 -> 4 ────┤ Rz(-π/2) ├───────┤ √X ├────┤ Rz(π) ├──────■────»
#                    └──────────┘       └────┘    └───────┘           »
#           c: 2/═════════════════════════════════════════════════════»
#                                                                     »
# «
# «ancilla_0 -> 0 ─────────────────────────────────────────────────────────
# «
# «ancilla_1 -> 1 ─────────────────────────────────────────────────────────
# «                                         ┌────┐       ┌──────────┐   ┌─┐
# «      q_1 -> 2 ─────────■────────────────┤ √X ├───────┤ Rz(-π/2) ├───┤M├
# «                      ┌─┴─┐       ┌──────┴────┴──────┐└──────────┘   └╥┘
# «      q_2 -> 3 ───────┤ X ├───────┤ Delay(18240[dt]) ├────────────────╫─
# «               ┌──────┴───┴──────┐└──────┬────┬──────┘┌──────────┐┌─┐ ║
# «      q_0 -> 4 ┤ Delay(1696[dt]) ├───────┤ √X ├───────┤ Rz(-π/2) ├┤M├─╫─
# «               └─────────────────┘       └────┘       └──────────┘└╥┘ ║
# «          c: 2/════════════════════════════════════════════════════╩══╩═
# «                                                                   0  1
# ============================================
# ============================================
# ibmq_manila
#                ┌──────────────────┐                                 »
# ancilla_0 -> 0 ┤ Delay(28272[dt]) ├─────────────────────────────────»
#                └───┬──────────┬───┘   ┌────┐    ┌───────┐           »
#       q_0 -> 1 ────┤ Rz(-π/2) ├───────┤ √X ├────┤ Rz(π) ├──────■────»
#                    ├─────────┬┘       ├────┤   ┌┴───────┴─┐  ┌─┴─┐  »
#       q_2 -> 2 ────┤ Rz(π/2) ├────────┤ √X ├───┤ Rz(-π/2) ├──┤ X ├──»
#                ┌───┴─────────┴───┐ ┌──┴────┴──┐└──┬────┬──┘┌─┴───┴─┐»
#       q_1 -> 3 ┤ Delay(2112[dt]) ├─┤ Rz(-π/2) ├───┤ √X ├───┤ Rz(π) ├»
#                ├─────────────────┴┐└──────────┘   └────┘   └───────┘»
# ancilla_1 -> 4 ┤ Delay(28272[dt]) ├─────────────────────────────────»
#                └──────────────────┘                                 »
#           c: 2/═════════════════════════════════════════════════════»
#                                                                     »
# «
# «ancilla_0 -> 0 ─────────────────────────────────────────────────────────
# «               ┌─────────────────┐       ┌────┐       ┌──────────┐┌─┐
# «      q_0 -> 1 ┤ Delay(1760[dt]) ├───────┤ √X ├───────┤ Rz(-π/2) ├┤M├───
# «               └──────┬───┬──────┘┌──────┴────┴──────┐└──────────┘└╥┘
# «      q_2 -> 2 ───────┤ X ├───────┤ Delay(24240[dt]) ├─────────────╫────
# «                      └─┬─┘       └──────┬────┬──────┘┌──────────┐ ║ ┌─┐
# «      q_1 -> 3 ─────────■────────────────┤ √X ├───────┤ Rz(-π/2) ├─╫─┤M├
# «                                         └────┘       └──────────┘ ║ └╥┘
# «ancilla_1 -> 4 ────────────────────────────────────────────────────╫──╫─
# «                                                                   ║  ║
# «          c: 2/════════════════════════════════════════════════════╩══╩═
# «                                                                   0  1
# ============================================
# ============================================
# ibmq_quito
#                ┌──────────────────┐                                      »
# ancilla_0 -> 0 ┤ Delay(27248[dt]) ├──────────────────────────────────────»
#                └───┬─────────┬────┘   ┌────┐   ┌──────────┐         ┌───┐»
#       q_2 -> 1 ────┤ Rz(π/2) ├────────┤ √X ├───┤ Rz(-π/2) ├─────────┤ X ├»
#                ┌───┴─────────┴───┐ ┌──┴────┴──┐└──┬────┬──┘┌───────┐└─┬─┘»
#       q_1 -> 2 ┤ Delay(1664[dt]) ├─┤ Rz(-π/2) ├───┤ √X ├───┤ Rz(π) ├──┼──»
#                └───┬──────────┬──┘ └──┬────┬──┘ ┌─┴────┴┐  └───────┘  │  »
#       q_0 -> 3 ────┤ Rz(-π/2) ├───────┤ √X ├────┤ Rz(π) ├─────────────■──»
#                ┌───┴──────────┴───┐   └────┘    └───────┘                »
# ancilla_1 -> 4 ┤ Delay(27248[dt]) ├──────────────────────────────────────»
#                └──────────────────┘                                      »
#           c: 2/══════════════════════════════════════════════════════════»
#                                                                          »
# «
# «ancilla_0 -> 0 ─────────────────────────────────────────────────────────
# «                      ┌───┐       ┌──────────────────┐
# «      q_2 -> 1 ───────┤ X ├───────┤ Delay(24240[dt]) ├──────────────────
# «                      └─┬─┘       └──────┬────┬──────┘┌──────────┐   ┌─┐
# «      q_1 -> 2 ─────────■────────────────┤ √X ├───────┤ Rz(-π/2) ├───┤M├
# «               ┌─────────────────┐       ├────┤       ├──────────┤┌─┐└╥┘
# «      q_0 -> 3 ┤ Delay(1184[dt]) ├───────┤ √X ├───────┤ Rz(-π/2) ├┤M├─╫─
# «               └─────────────────┘       └────┘       └──────────┘└╥┘ ║
# «ancilla_1 -> 4 ────────────────────────────────────────────────────╫──╫─
# «                                                                   ║  ║
# «          c: 2/════════════════════════════════════════════════════╩══╩═
# «                                                                   0  1
# ============================================
# ============================================
# ibmq_belem
#                ┌──────────────────┐                                 »
# ancilla_0 -> 0 ┤ Delay(28848[dt]) ├─────────────────────────────────»
#                ├─────────────────┬┘┌──────────┐   ┌────┐   ┌───────┐»
#       q_1 -> 1 ┤ Delay(2496[dt]) ├─┤ Rz(-π/2) ├───┤ √X ├───┤ Rz(π) ├»
#                ├─────────────────┴┐└──────────┘   └────┘   └───────┘»
# ancilla_1 -> 2 ┤ Delay(28848[dt]) ├─────────────────────────────────»
#                └───┬─────────┬────┘   ┌────┐   ┌──────────┐  ┌───┐  »
#       q_2 -> 3 ────┤ Rz(π/2) ├────────┤ √X ├───┤ Rz(-π/2) ├──┤ X ├──»
#                    ├─────────┴┐       ├────┤   └┬───────┬─┘  └─┬─┘  »
#       q_0 -> 4 ────┤ Rz(-π/2) ├───────┤ √X ├────┤ Rz(π) ├──────■────»
#                    └──────────┘       └────┘    └───────┘           »
#           c: 2/═════════════════════════════════════════════════════»
#                                                                     »
# «
# «ancilla_0 -> 0 ─────────────────────────────────────────────────────────
# «                                         ┌────┐       ┌──────────┐   ┌─┐
# «      q_1 -> 1 ─────────■────────────────┤ √X ├───────┤ Rz(-π/2) ├───┤M├
# «                        │                └────┘       └──────────┘   └╥┘
# «ancilla_1 -> 2 ─────────┼─────────────────────────────────────────────╫─
# «                      ┌─┴─┐       ┌──────────────────┐                ║
# «      q_2 -> 3 ───────┤ X ├───────┤ Delay(24240[dt]) ├────────────────╫─
# «               ┌──────┴───┴──────┐└──────┬────┬──────┘┌──────────┐┌─┐ ║
# «      q_0 -> 4 ┤ Delay(1952[dt]) ├───────┤ √X ├───────┤ Rz(-π/2) ├┤M├─╫─
# «               └─────────────────┘       └────┘       └──────────┘└╥┘ ║
# «          c: 2/════════════════════════════════════════════════════╩══╩═
# «                                                                   0  1
# ============================================
# ============================================
# ibmq_casablanca
#                ┌──────────────────┐                                 »
# ancilla_0 -> 0 ┤ Delay(30160[dt]) ├─────────────────────────────────»
#                ├──────────────────┤                                 »
# ancilla_1 -> 1 ┤ Delay(30160[dt]) ├─────────────────────────────────»
#                ├──────────────────┤                                 »
# ancilla_2 -> 2 ┤ Delay(30160[dt]) ├─────────────────────────────────»
#                ├─────────────────┬┘┌──────────┐   ┌────┐   ┌───────┐»
#       q_1 -> 3 ┤ Delay(1376[dt]) ├─┤ Rz(-π/2) ├───┤ √X ├───┤ Rz(π) ├»
#                ├─────────────────┴┐└──────────┘   └────┘   └───────┘»
# ancilla_3 -> 4 ┤ Delay(30160[dt]) ├─────────────────────────────────»
#                └───┬─────────┬────┘   ┌────┐   ┌──────────┐  ┌───┐  »
#       q_2 -> 5 ────┤ Rz(π/2) ├────────┤ √X ├───┤ Rz(-π/2) ├──┤ X ├──»
#                    ├─────────┴┐       ├────┤   └┬───────┬─┘  └─┬─┘  »
#       q_0 -> 6 ────┤ Rz(-π/2) ├───────┤ √X ├────┤ Rz(π) ├──────■────»
#                    └──────────┘       └────┘    └───────┘           »
#           c: 2/═════════════════════════════════════════════════════»
#                                                                     »
# «
# «ancilla_0 -> 0 ─────────────────────────────────────────────────────────
# «
# «ancilla_1 -> 1 ─────────────────────────────────────────────────────────
# «
# «ancilla_2 -> 2 ─────────────────────────────────────────────────────────
# «                                         ┌────┐       ┌──────────┐   ┌─┐
# «      q_1 -> 3 ─────────■────────────────┤ √X ├───────┤ Rz(-π/2) ├───┤M├
# «                        │                └────┘       └──────────┘   └╥┘
# «ancilla_3 -> 4 ─────────┼─────────────────────────────────────────────╫─
# «                      ┌─┴─┐       ┌──────────────────┐                ║
# «      q_2 -> 5 ───────┤ X ├───────┤ Delay(26672[dt]) ├────────────────╫─
# «               ┌──────┴───┴──────┐└──────┬────┬──────┘┌──────────┐┌─┐ ║
# «      q_0 -> 6 ┤ Delay(1952[dt]) ├───────┤ √X ├───────┤ Rz(-π/2) ├┤M├─╫─
# «               └─────────────────┘       └────┘       └──────────┘└╥┘ ║
# «          c: 2/════════════════════════════════════════════════════╩══╩═
# «                                                                   0  1
# ============================================
# ============================================
# ibmq_jakarta
#                ┌──────────────────┐                                 »
# ancilla_0 -> 0 ┤ Delay(27824[dt]) ├─────────────────────────────────»
#                └───┬──────────┬───┘   ┌────┐    ┌───────┐           »
#       q_0 -> 1 ────┤ Rz(-π/2) ├───────┤ √X ├────┤ Rz(π) ├──────■────»
#                ┌───┴──────────┴───┐   └────┘    └───────┘      │    »
# ancilla_1 -> 2 ┤ Delay(27824[dt]) ├────────────────────────────┼────»
#                └───┬─────────┬────┘   ┌────┐   ┌──────────┐  ┌─┴─┐  »
#       q_2 -> 3 ────┤ Rz(π/2) ├────────┤ √X ├───┤ Rz(-π/2) ├──┤ X ├──»
#                ┌───┴─────────┴────┐   └────┘   └──────────┘  └───┘  »
# ancilla_2 -> 4 ┤ Delay(27824[dt]) ├─────────────────────────────────»
#                ├─────────────────┬┘┌──────────┐   ┌────┐   ┌───────┐»
#       q_1 -> 5 ┤ Delay(1728[dt]) ├─┤ Rz(-π/2) ├───┤ √X ├───┤ Rz(π) ├»
#                ├─────────────────┴┐└──────────┘   └────┘   └───────┘»
# ancilla_3 -> 6 ┤ Delay(27824[dt]) ├─────────────────────────────────»
#                └──────────────────┘                                 »
#           c: 2/═════════════════════════════════════════════════════»
#                                                                     »
# «
# «ancilla_0 -> 0 ─────────────────────────────────────────────────────────
# «               ┌─────────────────┐       ┌────┐       ┌──────────┐┌─┐
# «      q_0 -> 1 ┤ Delay(1696[dt]) ├───────┤ √X ├───────┤ Rz(-π/2) ├┤M├───
# «               └─────────────────┘       └────┘       └──────────┘└╥┘
# «ancilla_1 -> 2 ────────────────────────────────────────────────────╫────
# «                      ┌───┐       ┌──────────────────┐             ║
# «      q_2 -> 3 ───────┤ X ├───────┤ Delay(24240[dt]) ├─────────────╫────
# «                      └─┬─┘       └──────────────────┘             ║
# «ancilla_2 -> 4 ─────────┼──────────────────────────────────────────╫────
# «                        │                ┌────┐       ┌──────────┐ ║ ┌─┐
# «      q_1 -> 5 ─────────■────────────────┤ √X ├───────┤ Rz(-π/2) ├─╫─┤M├
# «                                         └────┘       └──────────┘ ║ └╥┘
# «ancilla_3 -> 6 ────────────────────────────────────────────────────╫──╫─
# «                                                                   ║  ║
# «          c: 2/════════════════════════════════════════════════════╩══╩═
# «                                                                   0  1
# ============================================
# ============================================
# ibm_lagos
#                ┌─────────────────┐                                 »
# ancilla_0 -> 0 ┤ Delay(6336[dt]) ├─────────────────────────────────»
#                ├─────────────────┤┌──────────┐   ┌────┐   ┌───────┐»
#       q_1 -> 1 ┤ Delay(1344[dt]) ├┤ Rz(-π/2) ├───┤ √X ├───┤ Rz(π) ├»
#                ├─────────────────┤└──────────┘   └────┘   └───────┘»
# ancilla_1 -> 2 ┤ Delay(6336[dt]) ├─────────────────────────────────»
#                └───┬─────────┬───┘   ┌────┐   ┌──────────┐  ┌───┐  »
#       q_2 -> 3 ────┤ Rz(π/2) ├───────┤ √X ├───┤ Rz(-π/2) ├──┤ X ├──»
#                ┌───┴─────────┴───┐   └────┘   └──────────┘  └─┬─┘  »
# ancilla_2 -> 4 ┤ Delay(6336[dt]) ├────────────────────────────┼────»
#                └───┬──────────┬──┘   ┌────┐    ┌───────┐      │    »
#       q_0 -> 5 ────┤ Rz(-π/2) ├──────┤ √X ├────┤ Rz(π) ├──────■────»
#                ┌───┴──────────┴──┐   └────┘    └───────┘           »
# ancilla_3 -> 6 ┤ Delay(6336[dt]) ├─────────────────────────────────»
#                └─────────────────┘                                 »
#           c: 2/════════════════════════════════════════════════════»
#                                                                    »
# «
# «ancilla_0 -> 0 ────────────────────────────────────────────────────────
# «                                         ┌────┐      ┌──────────┐   ┌─┐
# «      q_1 -> 1 ─────────■────────────────┤ √X ├──────┤ Rz(-π/2) ├───┤M├
# «                        │                └────┘      └──────────┘   └╥┘
# «ancilla_1 -> 2 ─────────┼────────────────────────────────────────────╫─
# «                      ┌─┴─┐       ┌─────────────────┐                ║
# «      q_2 -> 3 ───────┤ X ├───────┤ Delay(3328[dt]) ├────────────────╫─
# «                      └───┘       └─────────────────┘                ║
# «ancilla_2 -> 4 ──────────────────────────────────────────────────────╫─
# «               ┌─────────────────┐       ┌────┐      ┌──────────┐┌─┐ ║
# «      q_0 -> 5 ┤ Delay(1504[dt]) ├───────┤ √X ├──────┤ Rz(-π/2) ├┤M├─╫─
# «               └─────────────────┘       └────┘      └──────────┘└╥┘ ║
# «ancilla_3 -> 6 ───────────────────────────────────────────────────╫──╫─
# «                                                                  ║  ║
# «          c: 2/═══════════════════════════════════════════════════╩══╩═
# «                                                                  0  1
# ============================================
# ============================================
# ibm_perth
#                ┌─────────────────┐                                 »
# ancilla_0 -> 0 ┤ Delay(6624[dt]) ├─────────────────────────────────»
#                └───┬──────────┬──┘   ┌────┐    ┌───────┐           »
#       q_0 -> 1 ────┤ Rz(-π/2) ├──────┤ √X ├────┤ Rz(π) ├──────■────»
#                ┌───┴──────────┴──┐   └────┘    └───────┘      │    »
# ancilla_1 -> 2 ┤ Delay(6624[dt]) ├────────────────────────────┼────»
#                └───┬─────────┬───┘   ┌────┐   ┌──────────┐  ┌─┴─┐  »
#       q_2 -> 3 ────┤ Rz(π/2) ├───────┤ √X ├───┤ Rz(-π/2) ├──┤ X ├──»
#                ┌───┴─────────┴───┐   └────┘   └──────────┘  └───┘  »
# ancilla_2 -> 4 ┤ Delay(6624[dt]) ├─────────────────────────────────»
#                ├─────────────────┤┌──────────┐   ┌────┐   ┌───────┐»
#       q_1 -> 5 ┤ Delay(1824[dt]) ├┤ Rz(-π/2) ├───┤ √X ├───┤ Rz(π) ├»
#                ├─────────────────┤└──────────┘   └────┘   └───────┘»
# ancilla_3 -> 6 ┤ Delay(6624[dt]) ├─────────────────────────────────»
#                └─────────────────┘                                 »
#           c: 2/════════════════════════════════════════════════════»
#                                                                    »
# «
# «ancilla_0 -> 0 ────────────────────────────────────────────────────────
# «               ┌─────────────────┐       ┌────┐      ┌──────────┐┌─┐
# «      q_0 -> 1 ┤ Delay(1440[dt]) ├───────┤ √X ├──────┤ Rz(-π/2) ├┤M├───
# «               └─────────────────┘       └────┘      └──────────┘└╥┘
# «ancilla_1 -> 2 ───────────────────────────────────────────────────╫────
# «                      ┌───┐       ┌─────────────────┐             ║
# «      q_2 -> 3 ───────┤ X ├───────┤ Delay(3200[dt]) ├─────────────╫────
# «                      └─┬─┘       └─────────────────┘             ║
# «ancilla_2 -> 4 ─────────┼─────────────────────────────────────────╫────
# «                        │                ┌────┐      ┌──────────┐ ║ ┌─┐
# «      q_1 -> 5 ─────────■────────────────┤ √X ├──────┤ Rz(-π/2) ├─╫─┤M├
# «                                         └────┘      └──────────┘ ║ └╥┘
# «ancilla_3 -> 6 ───────────────────────────────────────────────────╫──╫─
# «                                                                  ║  ║
# «          c: 2/═══════════════════════════════════════════════════╩══╩═
# «                                                                  0  1
# ============================================

# %%
j = 9
print(device[j])
transpiled_dj[j].draw('mpl')
# Out:
# ibm_perth

# %%
qcx = QuantumCircuit(3)
qcx.cx(0,1)
qcx.h(0)
print(qcx)
print("============================================")
print(device[0])
transpiled_qcx = transpile(qcx, device[0], optimization_level=3, scheduling_method='alap')
print(transpiled_qcx)
print("============================================")
# Out:
#           ┌───┐
# q_0: ──■──┤ H ├
#      ┌─┴─┐└───┘
# q_1: ┤ X ├─────
#      └───┘
# q_2: ──────────
#
# ============================================
# ibmq_lima
#                                      ┌─────────┐    ┌────┐┌─────────┐
#       q_0 -> 0 ─────────■────────────┤ Rz(π/2) ├────┤ √X ├┤ Rz(π/2) ├
#                       ┌─┴─┐       ┌──┴─────────┴───┐└────┘└─────────┘
#       q_1 -> 1 ───────┤ X ├───────┤ Delay(160[dt]) ├─────────────────
#                ┌──────┴───┴──────┐└────────────────┘
#       q_2 -> 2 ┤ Delay(1536[dt]) ├───────────────────────────────────
#                ├─────────────────┤
# ancilla_0 -> 3 ┤ Delay(1536[dt]) ├───────────────────────────────────
#                ├─────────────────┤
# ancilla_1 -> 4 ┤ Delay(1536[dt]) ├───────────────────────────────────
#                └─────────────────┘
# ============================================

# %%
from qiskit import QuantumCircuit, transpile
from qiskit.visualization import plot_circuit_layout
from qiskit.test.mock import FakeVigo
from qiskit.transpiler import CouplingMap
# backend=device[9]
# qplot = transpile(ghz, backend, scheduling_method='alap')
# print("========",backend,"========")
plot_circuit_layout(transpiled_dj, backend)

# %%
#initialization
import matplotlib.pyplot as plt
import numpy as np

# importing Qiskit
from qiskit import IBMQ, Aer, assemble, transpile
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit.providers.ibmq import least_busy

# import basic plot tools
from qiskit.visualization import plot_histogram

# Load IBM Q account and get the least busy backend device
provider = IBMQ.load_account()
# provider = IBMQ.get_provider("ibm-q")
provider = IBMQ.get_provider(hub='ibm-q-education', group='yale-uni-2', project='cpsc647-quantum')
# device = provider.get_backend('ibmq_lima') #run on ibmq_lima (5-qbit QC)

# %%
device_names =  ['ibmq_lima', 'ibmq_bogota', 'ibmq_santiago', 'ibmq_manila', 'ibmq_quito', 'ibmq_belem', 'ibmq_casablanca', 'ibmq_jakarta', 'ibm_lagos', 'ibm_perth'  ]
device = [0]*len(device_names)
for i in range(len(device_names)):
    device[i] = provider.get_backend(device_names[i])
    print("Device", i , "=", device[i])
# Out:
# Device 0 = ibmq_lima
# Device 1 = ibmq_bogota
# Device 2 = ibmq_santiago
# Device 3 = ibmq_manila
# Device 4 = ibmq_quito
# Device 5 = ibmq_belem
# Device 6 = ibmq_casablanca
# Device 7 = ibmq_jakarta
# Device 8 = ibm_lagos
# Device 9 = ibm_perth

# %%
def bv_algorithm(s, n):
    # We need a circuit with n qubits, plus one auxiliary qubit
    # Also need n classical bits to write the output to
    bv_circuit = QuantumCircuit(n+1, n)

    # put auxiliary in state |->
    bv_circuit.h(n)
    bv_circuit.z(n)

    # Apply Hadamard gates before querying the oracle
    for i in range(n):
        bv_circuit.h(i)

    # Apply barrier 
#     bv_circuit.barrier()

    # Apply the inner-product oracle
    s = s[::-1] # reverse s to fit qiskit's qubit ordering
    for q in range(n):
        if s[q] == '0':
            bv_circuit.i(q)
        else:
            bv_circuit.cx(q, n)

    # Apply barrier 
#     bv_circuit.barrier()

    #Apply Hadamard gates after querying the oracle
    for i in range(n):
        bv_circuit.h(i)
    
    # Measurement
    for i in range(n):
        bv_circuit.measure(i, i)
    
    return bv_circuit

# %%
bv = bv_algorithm('10', 2)
print(bv)
# Out:
#      ┌───┐┌───┐┌───┐     ┌─┐
# q_0: ┤ H ├┤ I ├┤ H ├─────┤M├───
#      ├───┤└───┘└───┘┌───┐└╥┘┌─┐
# q_1: ┤ H ├───────■──┤ H ├─╫─┤M├
#      ├───┤┌───┐┌─┴─┐└───┘ ║ └╥┘
# q_2: ┤ H ├┤ Z ├┤ X ├──────╫──╫─
#      └───┘└───┘└───┘      ║  ║
# c: 2/═════════════════════╩══╩═
#                           0  1

# %%
aer_sim = Aer.get_backend('aer_simulator')
transpiled_circuit = transpile(bv, aer_sim)
qobj = assemble(transpiled_circuit)
results = aer_sim.run(qobj).result()
counts = results.get_counts()
plot_histogram(counts)

# %%
print("Running on device: ", device[1])
from qiskit.tools.monitor import job_monitor
transpiled_bv = transpile(bv, device[1], optimization_level=3, scheduling_method='alap')
# Out:
# Running on device:  ibmq_bogota

# %%
job = device[1].run(transpiled_bv)
job_monitor(job, interval=2)
# Out:
# Job Status: job has successfully run

# %%
results = job.result()
answer = results.get_counts(bv)
plot_histogram(answer)

# %%
from qiskit.tools.monitor import job_monitor

f = open("bv_CX_delay0.txt", "w")

for i in range(15):
    grover_circuit = grovers_algorithm_3(i)
    print("Running on device: ", device[0])
    transpiled_grover_circuit = transpile(grover_circuit, device[0], optimization_level=3, scheduling_method='alap')
    job = device[0].run(transpiled_grover_circuit) 
    job_monitor(job, interval=2)

    results = job.result()
    answer = results.get_counts(grover_circuit)
    plot_histogram(answer)

    prob1 = int(answer['00101'])/1000
    prob2 = int(answer['00110'])/1000
    print(i, prob1, prob2)
    f.write(str(i))
    f.write(str(", "))
    f.write(str(prob1))
    f.write(str(", "))
    f.write(str(prob2))
    f.write(str("\n"))
    
f.close()

# %%
# Out:
#      ┌───┐      ░ ┌───┐ ░ ┌───┐┌─┐
# q_0: ┤ H ├──────░─┤ I ├─░─┤ H ├┤M├───
#      ├───┤      ░ └───┘ ░ ├───┤└╥┘┌─┐
# q_1: ┤ H ├──────░───■───░─┤ H ├─╫─┤M├
#      ├───┤┌───┐ ░ ┌─┴─┐ ░ └───┘ ║ └╥┘
# q_2: ┤ H ├┤ Z ├─░─┤ X ├─░───────╫──╫─
#      └───┘└───┘ ░ └───┘ ░       ║  ║
# c: 2/═══════════════════════════╩══╩═
#                                 0  1

# %% [markdown]
# # Duration Analysis Code

# %%
transpiled_bv = [0]*len(device)
for i in range(len(device)):
    print("============================================")
    print(device[i])
#     transpiled_q[i] = transpile(q, device[i], optimization_level=3, scheduling_method='alap')
    transpiled_bv[i] = transpile(bv, device[i], optimization_level=3, scheduling_method='alap')
    print(transpiled_bv[i])
    print("============================================")
# Out:
# ============================================
# ibmq_lima
#                    ┌─────────┐     ┌────┐┌─────────┐  ░ ┌─────────────────┐ ░ »
#       q_0 -> 0 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├──░─┤ Delay(1504[dt]) ├─░─»
#                    ├─────────┤     ├────┤├─────────┤  ░ └─────────────────┘ ░ »
#       q_1 -> 1 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├──░──────────■──────────░─»
#                    ├─────────┤     ├────┤├─────────┴┐ ░        ┌─┴─┐        ░ »
#       q_2 -> 2 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(-π/2) ├─░────────┤ X ├────────░─»
#                ┌───┴─────────┴────┐└────┘└──────────┘ ░        └───┘        ░ »
# ancilla_0 -> 3 ┤ Delay(25904[dt]) ├───────────────────────────────────────────»
#                ├──────────────────┤                                           »
# ancilla_1 -> 4 ┤ Delay(25904[dt]) ├───────────────────────────────────────────»
#                └──────────────────┘                                           »
#           c: 2/═══════════════════════════════════════════════════════════════»
#                                                                               »
# «                   ┌─────────┐     ┌────┐┌─────────┐┌─┐
# «      q_0 -> 0 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├┤M├───
# «                   ├─────────┤     ├────┤├─────────┤└╥┘┌─┐
# «      q_1 -> 1 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├─╫─┤M├
# «               ┌───┴─────────┴────┐└────┘└─────────┘ ║ └╥┘
# «      q_2 -> 2 ┤ Delay(24240[dt]) ├──────────────────╫──╫─
# «               └──────────────────┘                  ║  ║
# «ancilla_0 -> 3 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «ancilla_1 -> 4 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «          c: 2/══════════════════════════════════════╩══╩═
# «                                                     0  1
# ============================================
# ============================================
# ibmq_bogota
#                    ┌─────────┐     ┌────┐┌─────────┐  ░ ┌─────────────────┐ ░ »
#       q_0 -> 0 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├──░─┤ Delay(1344[dt]) ├─░─»
#                    ├─────────┤     ├────┤├─────────┤  ░ └─────────────────┘ ░ »
#       q_1 -> 1 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├──░──────────■──────────░─»
#                    ├─────────┤     ├────┤├─────────┴┐ ░        ┌─┴─┐        ░ »
#       q_2 -> 2 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(-π/2) ├─░────────┤ X ├────────░─»
#                ┌───┴─────────┴────┐└────┘└──────────┘ ░        └───┘        ░ »
# ancilla_0 -> 3 ┤ Delay(24384[dt]) ├───────────────────────────────────────────»
#                ├──────────────────┤                                           »
# ancilla_1 -> 4 ┤ Delay(24384[dt]) ├───────────────────────────────────────────»
#                └──────────────────┘                                           »
#           c: 2/═══════════════════════════════════════════════════════════════»
#                                                                               »
# «                   ┌─────────┐     ┌────┐┌─────────┐┌─┐
# «      q_0 -> 0 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├┤M├───
# «                   ├─────────┤     ├────┤├─────────┤└╥┘┌─┐
# «      q_1 -> 1 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├─╫─┤M├
# «               ┌───┴─────────┴────┐└────┘└─────────┘ ║ └╥┘
# «      q_2 -> 2 ┤ Delay(22880[dt]) ├──────────────────╫──╫─
# «               └──────────────────┘                  ║  ║
# «ancilla_0 -> 3 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «ancilla_1 -> 4 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «          c: 2/══════════════════════════════════════╩══╩═
# «                                                     0  1
# ============================================
# ============================================
# ibmq_santiago
#                    ┌─────────┐     ┌────┐┌─────────┐  ░ ┌─────────────────┐ ░ »
#       q_0 -> 0 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├──░─┤ Delay(1600[dt]) ├─░─»
#                    ├─────────┤     ├────┤├─────────┤  ░ └─────────────────┘ ░ »
#       q_1 -> 1 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├──░──────────■──────────░─»
#                    ├─────────┤     ├────┤├─────────┴┐ ░        ┌─┴─┐        ░ »
#       q_2 -> 2 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(-π/2) ├─░────────┤ X ├────────░─»
#                ┌───┴─────────┴────┐└────┘└──────────┘ ░        └───┘        ░ »
# ancilla_0 -> 3 ┤ Delay(20000[dt]) ├───────────────────────────────────────────»
#                ├──────────────────┤                                           »
# ancilla_1 -> 4 ┤ Delay(20000[dt]) ├───────────────────────────────────────────»
#                └──────────────────┘                                           »
#           c: 2/═══════════════════════════════════════════════════════════════»
#                                                                               »
# «                   ┌─────────┐     ┌────┐┌─────────┐┌─┐
# «      q_0 -> 0 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├┤M├───
# «                   ├─────────┤     ├────┤├─────────┤└╥┘┌─┐
# «      q_1 -> 1 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├─╫─┤M├
# «               ┌───┴─────────┴────┐└────┘└─────────┘ ║ └╥┘
# «      q_2 -> 2 ┤ Delay(18240[dt]) ├──────────────────╫──╫─
# «               └──────────────────┘                  ║  ║
# «ancilla_0 -> 3 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «ancilla_1 -> 4 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «          c: 2/══════════════════════════════════════╩══╩═
# «                                                     0  1
# ============================================
# ============================================
# ibmq_manila
#                    ┌─────────┐     ┌────┐┌─────────┐  ░ ┌─────────────────┐ ░ »
#       q_0 -> 0 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├──░─┤ Delay(2112[dt]) ├─░─»
#                    ├─────────┤     ├────┤├─────────┤  ░ └─────────────────┘ ░ »
#       q_1 -> 1 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├──░──────────■──────────░─»
#                    ├─────────┤     ├────┤├─────────┴┐ ░        ┌─┴─┐        ░ »
#       q_2 -> 2 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(-π/2) ├─░────────┤ X ├────────░─»
#                ┌───┴─────────┴────┐└────┘└──────────┘ ░        └───┘        ░ »
# ancilla_0 -> 3 ┤ Delay(26512[dt]) ├───────────────────────────────────────────»
#                ├──────────────────┤                                           »
# ancilla_1 -> 4 ┤ Delay(26512[dt]) ├───────────────────────────────────────────»
#                └──────────────────┘                                           »
#           c: 2/═══════════════════════════════════════════════════════════════»
#                                                                               »
# «                   ┌─────────┐     ┌────┐┌─────────┐┌─┐
# «      q_0 -> 0 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├┤M├───
# «                   ├─────────┤     ├────┤├─────────┤└╥┘┌─┐
# «      q_1 -> 1 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├─╫─┤M├
# «               ┌───┴─────────┴────┐└────┘└─────────┘ ║ └╥┘
# «      q_2 -> 2 ┤ Delay(24240[dt]) ├──────────────────╫──╫─
# «               └──────────────────┘                  ║  ║
# «ancilla_0 -> 3 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «ancilla_1 -> 4 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «          c: 2/══════════════════════════════════════╩══╩═
# «                                                     0  1
# ============================================
# ============================================
# ibmq_quito
#                    ┌─────────┐     ┌────┐┌─────────┐  ░ ┌─────────────────┐ ░ »
#       q_0 -> 0 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├──░─┤ Delay(1344[dt]) ├─░─»
#                    ├─────────┤     ├────┤├─────────┤  ░ └─────────────────┘ ░ »
#       q_1 -> 1 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├──░──────────■──────────░─»
#                    ├─────────┤     ├────┤├─────────┴┐ ░        ┌─┴─┐        ░ »
#       q_2 -> 2 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(-π/2) ├─░────────┤ X ├────────░─»
#                ┌───┴─────────┴────┐└────┘└──────────┘ ░        └───┘        ░ »
# ancilla_0 -> 3 ┤ Delay(25744[dt]) ├───────────────────────────────────────────»
#                ├──────────────────┤                                           »
# ancilla_1 -> 4 ┤ Delay(25744[dt]) ├───────────────────────────────────────────»
#                └──────────────────┘                                           »
#           c: 2/═══════════════════════════════════════════════════════════════»
#                                                                               »
# «                   ┌─────────┐     ┌────┐┌─────────┐┌─┐
# «      q_0 -> 0 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├┤M├───
# «                   ├─────────┤     ├────┤├─────────┤└╥┘┌─┐
# «      q_1 -> 1 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├─╫─┤M├
# «               ┌───┴─────────┴────┐└────┘└─────────┘ ║ └╥┘
# «      q_2 -> 2 ┤ Delay(24240[dt]) ├──────────────────╫──╫─
# «               └──────────────────┘                  ║  ║
# «ancilla_0 -> 3 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «ancilla_1 -> 4 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «          c: 2/══════════════════════════════════════╩══╩═
# «                                                     0  1
# ============================================
# ============================================
# ibmq_belem
#                    ┌─────────┐     ┌────┐┌─────────┐  ░ ┌─────────────────┐ ░ »
#       q_0 -> 0 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├──░─┤ Delay(2016[dt]) ├─░─»
#                    ├─────────┤     ├────┤├─────────┤  ░ └─────────────────┘ ░ »
#       q_1 -> 1 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├──░──────────■──────────░─»
#                    ├─────────┤     ├────┤├─────────┴┐ ░        ┌─┴─┐        ░ »
#       q_2 -> 2 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(-π/2) ├─░────────┤ X ├────────░─»
#                ┌───┴─────────┴────┐└────┘└──────────┘ ░        └───┘        ░ »
# ancilla_0 -> 3 ┤ Delay(26416[dt]) ├───────────────────────────────────────────»
#                ├──────────────────┤                                           »
# ancilla_1 -> 4 ┤ Delay(26416[dt]) ├───────────────────────────────────────────»
#                └──────────────────┘                                           »
#           c: 2/═══════════════════════════════════════════════════════════════»
#                                                                               »
# «                   ┌─────────┐     ┌────┐┌─────────┐┌─┐
# «      q_0 -> 0 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├┤M├───
# «                   ├─────────┤     ├────┤├─────────┤└╥┘┌─┐
# «      q_1 -> 1 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├─╫─┤M├
# «               ┌───┴─────────┴────┐└────┘└─────────┘ ║ └╥┘
# «      q_2 -> 2 ┤ Delay(24240[dt]) ├──────────────────╫──╫─
# «               └──────────────────┘                  ║  ║
# «ancilla_0 -> 3 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «ancilla_1 -> 4 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «          c: 2/══════════════════════════════════════╩══╩═
# «                                                     0  1
# ============================================
# ============================================
# ibmq_casablanca
#                    ┌─────────┐     ┌────┐┌─────────┐  ░ ┌─────────────────┐ ░ »
#       q_0 -> 0 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├──░─┤ Delay(1824[dt]) ├─░─»
#                    ├─────────┤     ├────┤├─────────┤  ░ └─────────────────┘ ░ »
#       q_1 -> 1 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├──░──────────■──────────░─»
#                    ├─────────┤     ├────┤├─────────┴┐ ░        ┌─┴─┐        ░ »
#       q_2 -> 2 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(-π/2) ├─░────────┤ X ├────────░─»
#                ┌───┴─────────┴────┐└────┘└──────────┘ ░        └───┘        ░ »
# ancilla_0 -> 3 ┤ Delay(28656[dt]) ├───────────────────────────────────────────»
#                ├──────────────────┤                                           »
# ancilla_1 -> 4 ┤ Delay(28656[dt]) ├───────────────────────────────────────────»
#                ├──────────────────┤                                           »
# ancilla_2 -> 5 ┤ Delay(28656[dt]) ├───────────────────────────────────────────»
#                ├──────────────────┤                                           »
# ancilla_3 -> 6 ┤ Delay(28656[dt]) ├───────────────────────────────────────────»
#                └──────────────────┘                                           »
#           c: 2/═══════════════════════════════════════════════════════════════»
#                                                                               »
# «                   ┌─────────┐     ┌────┐┌─────────┐┌─┐
# «      q_0 -> 0 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├┤M├───
# «                   ├─────────┤     ├────┤├─────────┤└╥┘┌─┐
# «      q_1 -> 1 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├─╫─┤M├
# «               ┌───┴─────────┴────┐└────┘└─────────┘ ║ └╥┘
# «      q_2 -> 2 ┤ Delay(26672[dt]) ├──────────────────╫──╫─
# «               └──────────────────┘                  ║  ║
# «ancilla_0 -> 3 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «ancilla_1 -> 4 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «ancilla_2 -> 5 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «ancilla_3 -> 6 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «          c: 2/══════════════════════════════════════╩══╩═
# «                                                     0  1
# ============================================
# ============================================
# ibmq_jakarta
#                    ┌─────────┐     ┌────┐┌─────────┐  ░ ┌─────────────────┐ ░ »
#       q_0 -> 0 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├──░─┤ Delay(1280[dt]) ├─░─»
#                    ├─────────┤     ├────┤├─────────┤  ░ └─────────────────┘ ░ »
#       q_1 -> 1 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├──░──────────■──────────░─»
#                    ├─────────┤     ├────┤├─────────┴┐ ░        ┌─┴─┐        ░ »
#       q_2 -> 2 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(-π/2) ├─░────────┤ X ├────────░─»
#                ┌───┴─────────┴────┐└────┘└──────────┘ ░        └───┘        ░ »
# ancilla_0 -> 3 ┤ Delay(25680[dt]) ├───────────────────────────────────────────»
#                ├──────────────────┤                                           »
# ancilla_1 -> 4 ┤ Delay(25680[dt]) ├───────────────────────────────────────────»
#                ├──────────────────┤                                           »
# ancilla_2 -> 5 ┤ Delay(25680[dt]) ├───────────────────────────────────────────»
#                ├──────────────────┤                                           »
# ancilla_3 -> 6 ┤ Delay(25680[dt]) ├───────────────────────────────────────────»
#                └──────────────────┘                                           »
#           c: 2/═══════════════════════════════════════════════════════════════»
#                                                                               »
# «                   ┌─────────┐     ┌────┐┌─────────┐┌─┐
# «      q_0 -> 0 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├┤M├───
# «                   ├─────────┤     ├────┤├─────────┤└╥┘┌─┐
# «      q_1 -> 1 ────┤ Rz(π/2) ├─────┤ √X ├┤ Rz(π/2) ├─╫─┤M├
# «               ┌───┴─────────┴────┐└────┘└─────────┘ ║ └╥┘
# «      q_2 -> 2 ┤ Delay(24240[dt]) ├──────────────────╫──╫─
# «               └──────────────────┘                  ║  ║
# «ancilla_0 -> 3 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «ancilla_1 -> 4 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «ancilla_2 -> 5 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «ancilla_3 -> 6 ──────────────────────────────────────╫──╫─
# «                                                     ║  ║
# «          c: 2/══════════════════════════════════════╩══╩═
# «                                                     0  1
# ============================================
# ============================================
# ibm_lagos
#                    ┌─────────┐    ┌────┐┌─────────┐  ░ ┌─────────────────┐ ░ »
#       q_0 -> 0 ────┤ Rz(π/2) ├────┤ √X ├┤ Rz(π/2) ├──░─┤ Delay(1472[dt]) ├─░─»
#                    ├─────────┤    ├────┤├─────────┤  ░ └─────────────────┘ ░ »
#       q_1 -> 1 ────┤ Rz(π/2) ├────┤ √X ├┤ Rz(π/2) ├──░──────────■──────────░─»
#                    ├─────────┤    ├────┤├─────────┴┐ ░        ┌─┴─┐        ░ »
#       q_2 -> 2 ────┤ Rz(π/2) ├────┤ √X ├┤ Rz(-π/2) ├─░────────┤ X ├────────░─»
#                ┌───┴─────────┴───┐└────┘└──────────┘ ░        └───┘        ░ »
# ancilla_0 -> 3 ┤ Delay(4960[dt]) ├───────────────────────────────────────────»
#                ├─────────────────┤                                           »
# ancilla_1 -> 4 ┤ Delay(4960[dt]) ├───────────────────────────────────────────»
#                ├─────────────────┤                                           »
# ancilla_2 -> 5 ┤ Delay(4960[dt]) ├───────────────────────────────────────────»
#                ├─────────────────┤                                           »
# ancilla_3 -> 6 ┤ Delay(4960[dt]) ├───────────────────────────────────────────»
#                └─────────────────┘                                           »
#           c: 2/══════════════════════════════════════════════════════════════»
#                                                                              »
# «                   ┌─────────┐    ┌────┐┌─────────┐┌─┐
# «      q_0 -> 0 ────┤ Rz(π/2) ├────┤ √X ├┤ Rz(π/2) ├┤M├───
# «                   ├─────────┤    ├────┤├─────────┤└╥┘┌─┐
# «      q_1 -> 1 ────┤ Rz(π/2) ├────┤ √X ├┤ Rz(π/2) ├─╫─┤M├
# «               ┌───┴─────────┴───┐└────┘└─────────┘ ║ └╥┘
# «      q_2 -> 2 ┤ Delay(3328[dt]) ├──────────────────╫──╫─
# «               └─────────────────┘                  ║  ║
# «ancilla_0 -> 3 ─────────────────────────────────────╫──╫─
# «                                                    ║  ║
# «ancilla_1 -> 4 ─────────────────────────────────────╫──╫─
# «                                                    ║  ║
# «ancilla_2 -> 5 ─────────────────────────────────────╫──╫─
# «                                                    ║  ║
# «ancilla_3 -> 6 ─────────────────────────────────────╫──╫─
# «                                                    ║  ║
# «          c: 2/═════════════════════════════════════╩══╩═
# «                                                    0  1
# ============================================
# ============================================
# ibm_perth
#                    ┌─────────┐    ┌────┐┌─────────┐  ░ ┌─────────────────┐ ░ »
#       q_0 -> 0 ────┤ Rz(π/2) ├────┤ √X ├┤ Rz(π/2) ├──░─┤ Delay(1600[dt]) ├─░─»
#                    ├─────────┤    ├────┤├─────────┤  ░ └─────────────────┘ ░ »
#       q_1 -> 1 ────┤ Rz(π/2) ├────┤ √X ├┤ Rz(π/2) ├──░──────────■──────────░─»
#                    ├─────────┤    ├────┤├─────────┴┐ ░        ┌─┴─┐        ░ »
#       q_2 -> 2 ────┤ Rz(π/2) ├────┤ √X ├┤ Rz(-π/2) ├─░────────┤ X ├────────░─»
#                ┌───┴─────────┴───┐└────┘└──────────┘ ░        └───┘        ░ »
# ancilla_0 -> 3 ┤ Delay(4960[dt]) ├───────────────────────────────────────────»
#                ├─────────────────┤                                           »
# ancilla_1 -> 4 ┤ Delay(4960[dt]) ├───────────────────────────────────────────»
#                ├─────────────────┤                                           »
# ancilla_2 -> 5 ┤ Delay(4960[dt]) ├───────────────────────────────────────────»
#                ├─────────────────┤                                           »
# ancilla_3 -> 6 ┤ Delay(4960[dt]) ├───────────────────────────────────────────»
#                └─────────────────┘                                           »
#           c: 2/══════════════════════════════════════════════════════════════»
#                                                                              »
# «                   ┌─────────┐    ┌────┐┌─────────┐┌─┐
# «      q_0 -> 0 ────┤ Rz(π/2) ├────┤ √X ├┤ Rz(π/2) ├┤M├───
# «                   ├─────────┤    ├────┤├─────────┤└╥┘┌─┐
# «      q_1 -> 1 ────┤ Rz(π/2) ├────┤ √X ├┤ Rz(π/2) ├─╫─┤M├
# «               ┌───┴─────────┴───┐└────┘└─────────┘ ║ └╥┘
# «      q_2 -> 2 ┤ Delay(3200[dt]) ├──────────────────╫──╫─
# «               └─────────────────┘                  ║  ║
# «ancilla_0 -> 3 ─────────────────────────────────────╫──╫─
# «                                                    ║  ║
# «ancilla_1 -> 4 ─────────────────────────────────────╫──╫─
# «                                                    ║  ║
# «ancilla_2 -> 5 ─────────────────────────────────────╫──╫─
# «                                                    ║  ║
# «ancilla_3 -> 6 ─────────────────────────────────────╫──╫─
# «                                                    ║  ║
# «          c: 2/═════════════════════════════════════╩══╩═
# «                                                    0  1
# ============================================

# %%
j = 9
print(device[j])
transpiled_bv[j].draw('mpl')
# Out:
# ibm_perth

# %%
q =  QuantumCircuit(2)
q.cx(0,1)
print(q)
# Out:
#
# q_0: ──■──
#      ┌─┴─┐
# q_1: ┤ X ├
#      └───┘

# %%
transpiled_q = [0]*len(device)
for i in range(len(device)):
    print("============================================")
    print(device[i])
#     transpiled_q[i] = transpile(q, device[i], optimization_level=3, scheduling_method='alap')
    transpiled_q[i] = transpile(q, device[i], optimization_level=3, scheduling_method='alap')
    print(transpiled_q[i])
    print("============================================")
# Out:
# ============================================
# ibmq_lima
#
#       q_0 -> 0 ─────────■─────────
#                       ┌─┴─┐
#       q_1 -> 1 ───────┤ X ├───────
#                ┌──────┴───┴──────┐
# ancilla_0 -> 2 ┤ Delay(1376[dt]) ├
#                ├─────────────────┤
# ancilla_1 -> 3 ┤ Delay(1376[dt]) ├
#                ├─────────────────┤
# ancilla_2 -> 4 ┤ Delay(1376[dt]) ├
#                └─────────────────┘
# ============================================
# ============================================
# ibmq_bogota
#
#       q_0 -> 0 ─────────■─────────
#                       ┌─┴─┐
#       q_1 -> 1 ───────┤ X ├───────
#                ┌──────┴───┴──────┐
# ancilla_0 -> 2 ┤ Delay(3104[dt]) ├
#                ├─────────────────┤
# ancilla_1 -> 3 ┤ Delay(3104[dt]) ├
#                ├─────────────────┤
# ancilla_2 -> 4 ┤ Delay(3104[dt]) ├
#                └─────────────────┘
# ============================================
# ============================================
# ibmq_santiago
#
#       q_0 -> 0 ─────────■─────────
#                       ┌─┴─┐
#       q_1 -> 1 ───────┤ X ├───────
#                ┌──────┴───┴──────┐
# ancilla_0 -> 2 ┤ Delay(2368[dt]) ├
#                ├─────────────────┤
# ancilla_1 -> 3 ┤ Delay(2368[dt]) ├
#                ├─────────────────┤
# ancilla_2 -> 4 ┤ Delay(2368[dt]) ├
#                └─────────────────┘
# ============================================
# ============================================
# ibmq_manila
#
#       q_0 -> 0 ─────────■─────────
#                       ┌─┴─┐
#       q_1 -> 1 ───────┤ X ├───────
#                ┌──────┴───┴──────┐
# ancilla_0 -> 2 ┤ Delay(1248[dt]) ├
#                ├─────────────────┤
# ancilla_1 -> 3 ┤ Delay(1248[dt]) ├
#                ├─────────────────┤
# ancilla_2 -> 4 ┤ Delay(1248[dt]) ├
#                └─────────────────┘
# ============================================
# ============================================
# ibmq_quito
#
#       q_0 -> 0 ─────────■─────────
#                       ┌─┴─┐
#       q_1 -> 1 ───────┤ X ├───────
#                ┌──────┴───┴──────┐
# ancilla_0 -> 2 ┤ Delay(1056[dt]) ├
#                ├─────────────────┤
# ancilla_1 -> 3 ┤ Delay(1056[dt]) ├
#                ├─────────────────┤
# ancilla_2 -> 4 ┤ Delay(1056[dt]) ├
#                └─────────────────┘
# ============================================
# ============================================
# ibmq_belem
#
#       q_0 -> 0 ─────────■─────────
#                       ┌─┴─┐
#       q_1 -> 1 ───────┤ X ├───────
#                ┌──────┴───┴──────┐
# ancilla_0 -> 2 ┤ Delay(3648[dt]) ├
#                ├─────────────────┤
# ancilla_1 -> 3 ┤ Delay(3648[dt]) ├
#                ├─────────────────┤
# ancilla_2 -> 4 ┤ Delay(3648[dt]) ├
#                └─────────────────┘
# ============================================
# ============================================
# ibmq_casablanca
#
#       q_0 -> 0 ─────────■─────────
#                       ┌─┴─┐
#       q_1 -> 1 ───────┤ X ├───────
#                ┌──────┴───┴──────┐
# ancilla_0 -> 2 ┤ Delay(3424[dt]) ├
#                ├─────────────────┤
# ancilla_1 -> 3 ┤ Delay(3424[dt]) ├
#                ├─────────────────┤
# ancilla_2 -> 4 ┤ Delay(3424[dt]) ├
#                ├─────────────────┤
# ancilla_3 -> 5 ┤ Delay(3424[dt]) ├
#                ├─────────────────┤
# ancilla_4 -> 6 ┤ Delay(3424[dt]) ├
#                └─────────────────┘
# ============================================
# ============================================
# ibmq_jakarta
#
#       q_0 -> 0 ─────────■─────────
#                       ┌─┴─┐
#       q_1 -> 1 ───────┤ X ├───────
#                ┌──────┴───┴──────┐
# ancilla_0 -> 2 ┤ Delay(1056[dt]) ├
#                ├─────────────────┤
# ancilla_1 -> 3 ┤ Delay(1056[dt]) ├
#                ├─────────────────┤
# ancilla_2 -> 4 ┤ Delay(1056[dt]) ├
#                ├─────────────────┤
# ancilla_3 -> 5 ┤ Delay(1056[dt]) ├
#                ├─────────────────┤
# ancilla_4 -> 6 ┤ Delay(1056[dt]) ├
#                └─────────────────┘
# ============================================
# ============================================
# ibm_lagos
#
#       q_0 -> 0 ─────────■─────────
#                       ┌─┴─┐
#       q_1 -> 1 ───────┤ X ├───────
#                ┌──────┴───┴──────┐
# ancilla_0 -> 2 ┤ Delay(1376[dt]) ├
#                ├─────────────────┤
# ancilla_1 -> 3 ┤ Delay(1376[dt]) ├
#                ├─────────────────┤
# ancilla_2 -> 4 ┤ Delay(1376[dt]) ├
#                ├─────────────────┤
# ancilla_3 -> 5 ┤ Delay(1376[dt]) ├
#                ├─────────────────┤
# ancilla_4 -> 6 ┤ Delay(1376[dt]) ├
#                └─────────────────┘
# ============================================
# ============================================
# ibm_perth
#
#       q_0 -> 0 ─────────■─────────
#                       ┌─┴─┐
#       q_1 -> 1 ───────┤ X ├───────
#                ┌──────┴───┴──────┐
# ancilla_0 -> 2 ┤ Delay(1760[dt]) ├
#                ├─────────────────┤
# ancilla_1 -> 3 ┤ Delay(1760[dt]) ├
#                ├─────────────────┤
# ancilla_2 -> 4 ┤ Delay(1760[dt]) ├
#                ├─────────────────┤
# ancilla_3 -> 5 ┤ Delay(1760[dt]) ├
#                ├─────────────────┤
# ancilla_4 -> 6 ┤ Delay(1760[dt]) ├
#                └─────────────────┘
# ============================================
